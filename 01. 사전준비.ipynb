# %% [markdown]
# #01. 개발 환경 설정하기

# %% [markdown]
# #Google Colab 사용법#
#
# ## 참고자료
#
#
# *   [Google Colaboratory 입문자들을 위한 설명!](https://jisoo-coding.tistory.com/2) (2018.12)
# *   [Google Colab 사용하기](https://zzsza.github.io/data/2018/08/30/google-colab/) (2018.08)
# *   [Google Colab Free GPU Tutorial](https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d) (2018.01~09)
#
#
#
# ##구글 드라이브와 연동하여 구글 코랩 사용하기

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls -alg '/content/drive/My Drive/data'
# Out:
# total 6
# drwx------ 2 root 4096 Oct  7 05:49 cats_and_dogs_filtered
# -rw------- 1 root 1170 Oct  7 06:38 Titanic.csv

# %% [markdown]
# ##MNIST 데이터셋 다운로드한 후 convnet 훈련하는 파이썬 코드 실행하기
# * upload [mnist_cnn.py](https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py) file to colab notebookx folder which is located on your Google Drive.

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/test/mnist_cnn.py"

# %% [markdown]
# ## 데이터셋 다운로드하여 사용하기

# %%
# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -P "/content/drive/My Drive/data"
# Out:
# --2019-10-07 06:38:38--  https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170 (1.1K) [text/plain]
# Saving to: ‘/content/drive/My Drive/data/Titanic.csv’
#
# Titanic.csv         100%[===================>]   1.14K  --.-KB/s    in 0s
#
# 2019-10-07 06:38:38 (153 MB/s) - ‘/content/drive/My Drive/data/Titanic.csv’ saved [1170/1170]

# %%
import pandas as pd
titanic = pd.read_csv("/content/drive/My Drive/data/Titanic.csv")
titanic.head(5)
# Out:
#    Unnamed: 0 Class     Sex    Age Survived  Freq
# 0           1   1st    Male  Child       No     0
# 1           2   2nd    Male  Child       No     0
# 2           3   3rd    Male  Child       No    35
# 3           4  Crew    Male  Child       No     0
# 4           5   1st  Female  Child       No     0

# %% [markdown]
# ## Cloning Github Repo to Google Colab (깃허브 코드 코랩에서 실행하기)
#
#
#
# 1. 원하는 Git 링크 복사 (예; https://github.com/deeplearningzerotoall/TensorFlow)
# 2. Git clone 하기
# 3. 구글 드라이브에서 폴더 열기
# 4. 노트북 파일 열기
# 5. 실행

# %%
# !pwd
# !git clone https://github.com/deeplearningzerotoall/TensorFlow "/content/drive/My Drive/Colab Notebooks/zerotoall_tensorflow"
# Out:
# /content
# Cloning into '/content/drive/My Drive/Colab Notebooks/zerotoall_tensorflow'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 1145 (delta 21), reused 35 (delta 17), pack-reused 1101
# Receiving objects: 100% (1145/1145), 1.53 MiB | 2.91 MiB/s, done.
# Resolving deltas: 100% (705/705), done.

# %% [markdown]
# ## Working 디렉토리 변경하기

# %%
# !pwd

import os
os.chdir("drive/My Drive/Colab Notebooks")

# !pwd
# !ls
# Out:
# /content
# /content/drive/My Drive/Colab Notebooks
#  colab테스트.ipynb			    사전준비.ipynb
# 'hello_world.ipynb의 사본'		    test
# 'image_classification_part1.ipynb의 사본'   zerotoall_tensorflow
